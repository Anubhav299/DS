# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('loan_data_set.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#loan status for gender
pd.crosstab(df['Gender'],df['Loan_Status'])
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %% [markdown]
# # 1. Loan Status of Gender according to married status.

# %%
pd.crosstab([df.Gender,df.Married],df.Loan_Status)
# Out:
# Loan_Status       N    Y
# Gender Married
# Female No        29   51
#        Yes        8   23
# Male   No        49   81
#        Yes      101  256

# %% [markdown]
# # 2.Loan Status on Education Status and Property_Area

# %%
pd.crosstab([df.Education,df.Property_Area],df.Loan_Status)
# Out:
# Loan_Status                  N    Y
# Education    Property_Area
# Graduate     Rural          47   84
#              Semiurban      43  144
#              Urban          50  112
# Not Graduate Rural          22   26
#              Semiurban      11   35
#              Urban          19   21

# %% [markdown]
# # 3.Average Applicant Income according to Education and Sorting according to Gender.

# %%
pd.crosstab([df.Education],[df.Gender],values=df.ApplicantIncome,aggfunc=np.average)
# Out:
# Gender             Female         Male
# Education
# Graduate      4646.467391  5992.345745
# Not Graduate  4629.700000  3630.061947

# %% [markdown]
# # 4.Percentage of Loan given according to Credit_History

# %%
dt=pd.crosstab(df.Credit_History,df.Loan_Status)

# %%
dt
# Out:
# Loan_Status      N    Y
# Credit_History
# 0.0             82    7
# 1.0             97  378

# %%
dt/dt.sum()*100
# Out:
# Loan_Status             N          Y
# Credit_History
# 0.0             45.810056   1.818182
# 1.0             54.189944  98.181818

# %% [markdown]
# # 5. Percentage of Loan Status according to married status and Dependents.

# %%
dt1=pd.crosstab([df.Dependents,df.Married],df.Loan_Status)

# %%
dt1
# Out:
# Loan_Status          N    Y
# Dependents Married
# 0          No       61  110
#            Yes      46  128
# 1          No       10   13
#            Yes      26   53
# 2          No        3    5
#            Yes      22   71
# 3+         No        3    4
#            Yes      15   29

# %%
dt1/dt1.sum()*100
# Out:
# Loan_Status                 N          Y
# Dependents Married
# 0          No       32.795699  26.634383
#            Yes      24.731183  30.992736
# 1          No        5.376344   3.147700
#            Yes      13.978495  12.832930
# 2          No        1.612903   1.210654
#            Yes      11.827957  17.191283
# 3+         No        1.612903   0.968523
#            Yes       8.064516   7.021792
