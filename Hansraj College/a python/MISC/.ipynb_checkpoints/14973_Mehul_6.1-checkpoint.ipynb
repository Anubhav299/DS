# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#    Unnamed: 0  Unnamed: 0.1  Roll no.  Phy   Comp  Maths
# 0           0             0         1   10   20.0   30.0
# 1           1             1         2   20   30.0   40.0
# 2           2             2         3   30   40.0   50.0
# 3           3             3         4   40   50.0   60.0
# 4           4             4         5   50   60.0   70.0
# 5           5             5         6   60   70.0   80.0
# 6           6             6         7   70   80.0   90.0
# 7           7             7         8   80   90.0  100.0
# 8           8             8         9   90  100.0    NaN
# 9           9             9        10  100    NaN    NaN

# %%
pd.read_table('data.csv', sep=',')
# Out:
#    Unnamed: 0  Unnamed: 0.1  Roll no.  Phy   Comp  Maths
# 0           0             0         1   10   20.0   30.0
# 1           1             1         2   20   30.0   40.0
# 2           2             2         3   30   40.0   50.0
# 3           3             3         4   40   50.0   60.0
# 4           4             4         5   50   60.0   70.0
# 5           5             5         6   60   70.0   80.0
# 6           6             6         7   70   80.0   90.0
# 7           7             7         8   80   90.0  100.0
# 8           8             8         9   90  100.0    NaN
# 9           9             9        10  100    NaN    NaN

# %%
 pd.read_csv('data.csv', header=None)
# Out:
#       0           1         2    3      4      5
# 0   NaN  Unnamed: 0  Roll no.  Phy   Comp  Maths
# 1   0.0           0         1   10   20.0   30.0
# 2   1.0           1         2   20   30.0   40.0
# 3   2.0           2         3   30   40.0   50.0
# 4   3.0           3         4   40   50.0   60.0
# 5   4.0           4         5   50   60.0   70.0
# 6   5.0           5         6   60   70.0   80.0
# 7   6.0           6         7   70   80.0   90.0
# 8   7.0           7         8   80   90.0  100.0
# 9   8.0           8         9   90  100.0    NaN
# 10  9.0           9        10  100    NaN    NaN

# %%
 pd.read_csv('data.csv', names=['Roll no.','Phy','Comp','Maths'])
# Out:
#                 Roll no.  Phy   Comp  Maths
# NaN Unnamed: 0  Roll no.  Phy   Comp  Maths
# 0.0 0                  1   10   20.0   30.0
# 1.0 1                  2   20   30.0   40.0
# 2.0 2                  3   30   40.0   50.0
# 3.0 3                  4   40   50.0   60.0
# 4.0 4                  5   50   60.0   70.0
# 5.0 5                  6   60   70.0   80.0
# 6.0 6                  7   70   80.0   90.0
# 7.0 7                  8   80   90.0  100.0
# 8.0 8                  9   90  100.0    NaN
# 9.0 9                 10  100    NaN    NaN

# %%
pd.read_csv('data.csv')
# Out:
#    Unnamed: 0  Unnamed: 0.1  Roll no.  Phy   Comp  Maths
# 0           0             0         1   10   20.0   30.0
# 1           1             1         2   20   30.0   40.0
# 2           2             2         3   30   40.0   50.0
# 3           3             3         4   40   50.0   60.0
# 4           4             4         5   50   60.0   70.0
# 5           5             5         6   60   70.0   80.0
# 6           6             6         7   70   80.0   90.0
# 7           7             7         8   80   90.0  100.0
# 8           8             8         9   90  100.0    NaN
# 9           9             9        10  100    NaN    NaN

# %% [markdown]
# # Error

# %%
'data/csv_mindex.csv'
# Out:
# 'data/csv_mindex.csv'

# %%
pd.read_csv('data.csv',index_col=['key1', 'key2'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-bf90d39f8b26> in <module>
# ----> 1 pd.read_csv('data.csv',index_col=['key1', 'key2'])
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
list(open('data.csv'))

# %%
result = pd.read_table('data.csv', sep='\s+')
result

# %%
 pd.read_csv('data.csv',skiprows=[1, 2, 3],header=None)

# %%
pd.isnull(df)

# %%
result = pd.read_csv('data.csv', na_values=['NULL'])

# %%
result

# %%
sentinels = {'Comp': ['foo', 'NA'], 'Maths': ['two']}
pd.read_csv('data.csv', na_values=sentinels)

# %%
pd.read_csv('data.csv', nrows=5)

# %%
chunker = pd.read_csv('data.csv', chunksize=1000)
chunker

# %%
pd.read_csv('data.csv', chunksize=1000)
tot = pd.Series([])
for piece in chunker:
 tot = tot.add(piece['key'].value_counts(), fill_value=0)
tot = tot.sort_values(ascending=False)

# %% [markdown]
# # Error

# %%
df.to_csv('data.csv')

# %%
import sys
df.to_csv(sys.stdout, sep='|')
something|a|b|c|d|message
0|one|1|2|3.0|4
1|two|5|6|8|world
2|three|9|10|11.0|12|foo
# Out:
# |Unnamed: 0|Unnamed: 0.1|Roll no.|Phy|Comp|Maths
# 0|0|0|1|10|20.0|30.0
# 1|1|1|2|20|30.0|40.0
# 2|2|2|3|30|40.0|50.0
# 3|3|3|4|40|50.0|60.0
# 4|4|4|5|50|60.0|70.0
# 5|5|5|6|60|70.0|80.0
# 6|6|6|7|70|80.0|90.0
# 7|7|7|8|80|90.0|100.0
# 8|8|8|9|90|100.0|
# 9|9|9|10|100||
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f2bc1a062fd4> in <module>
#       1 import sys
#       2 df.to_csv(sys.stdout, sep='|')
# ----> 3 something|a|b|c|d|message
#       4 0|one|1|2|3.0|4
#       5 1|two|5|6|8|world
#
# NameError: name 'something' is not defined
